# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import re
import unidecode
import unicodedata

# %% [markdown]
# # Functions

# %%
def CreateDataframe(directoryPath):
    csvsCombined = pd.DataFrame([])
    for csv in os.listdir(directoryPath):
        if (csv[-4:] == '.csv'):
            df = pd.read_csv(directoryPath + '/' + csv)
            csvsCombined = csvsCombined.append(df)
    csvsCombined = csvsCombined.drop('Unnamed: 0', axis=1)
    csvsCombined.index = range(len(csvsCombined))    
    del df
    return csvsCombined

# %%
def EncodeText(text):
    try:
        text = unicode(text, 'utf-8')
    except TypeError:
        pass
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore')
    text = text.decode("utf-8")
    return str(text)

# %%
def CleanText(text):
    #text = unicode(text, 'utf-8')
    #text = unidecode.unidecode(text)
    text = EncodeText(text)
    #text = re.sub(r"[^A-Za-z ]+", " ", text)
    text = re.sub(r"[\n\r\x0c]", " ", text)
    text = re.sub(r" {2,}", " ", text)
    return str(text)

# %% [markdown]
# # Preprocessing

# %%
df = CreateDataframe('Annual reports')
df.head()
# Out:
#           Company Country Language Estimated Language Expected  Pages Number  \
# 0      Eiffage SA  France                eng               eng            88
# 1    Klepierre SA  France                eng               eng            59
# 2    NRJ Group SA  France                eng               eng           233
# 3  Air Liquide SA  France                eng               eng            96
# 4       Sanofi SA  France                eng               eng            97
#
#    Scan                                               Text  Year
# 0     0  22\r\r\n\r\r\nDirectors' Repor t\r\r\n\r\r\n2...  2001
# 1     0  2\r\r\n\r\r\nKLÉPIERRE\r\r\n\r\r\nIN\r\r\n\r\r...  2000
# 2     0  NNUAL REPORT\r\r\no\r\r\n\r\r\nSEPTEMBER 30 20...  2001
# 3     0  A\r\r\n\r\r\nI\r\r\n\r\r\nR\r\r\n\r\r\nL\r\r\n...  1999
# 4     0  financial\r\r\nreport\r\r\n\r\r\nContents\r\r...  2001

# %%
df['Text'][12]
# Out:
# "1\r\r\n\r\r\n9\r\r\n\r\r\n9\r\r\n\r\r\n9\r\r\n\r\r\nH\xc3\xb4tellerie\r\r\n\r\r\naccorservices.com\r\r\n\r\r\naccorhotel.com\r\r\n\r\r\ndocument\r\r\nde r\xc3\xa9f\xc3\xa9rence\r\r\nH\xc3\xb4tellerie\r\r\n\r\r\nServices\r\r\n\r\r\naccor.com\r\r\n\r\r\nAssembl\xc3\xa9e G\xc3\xa9n\xc3\xa9rale Mixte du 30 Mai 2000\r\r\n\r\r\n\x0cH i s t o r i q u e\r\r\n\r\r\n\xe2\x80\xa2 Prise de participation dans la cha\xc3\xaene h\xc3\xb4teli\xc3\xa8re\r\r\nPannonia (24 h\xc3\xb4tels), dans le cadre des privatisations\r\r\n\r\r\n1967\r\r\n\r\r\nen Hongrie.\r\r\n\xe2\x80\xa2 Paul Dubrule et G\xc3\xa9rard P\xc3\xa9lisson fondent la SIEH.\r\r\n\r\r\n\xe2\x80\xa2 Lancement du label Coralia pour l\xe2\x80\x99h\xc3\xb4tellerie de loisirs.\r\r\n\r\r\n\xe2\x80\xa2 Premier h\xc3\xb4tel Novotel \xc3\xa0 Lille.\r\r\n\r\r\n1974\r\r\n\r\r\n\xe2\x80\xa2 Ouverture du premier Ibis \xc3\xa0 Bordeaux.\r\r\n\r\r\n1994\r\r\n\r\r\nle domaine du voyage d\xe2\x80\x99affaires.\r\r\n\r\r\n\xe2\x80\xa2 Reprise de Courtepaille.\r\r\n\r\r\n1995\r\r\n\r\r\n\xe2\x80\xa2 Cession de Eurest \xc3\xa0 Compass : Accor est le premier\r\r\n\r\r\n1975\r\r\n\r\r\n\xe2\x80\xa2 Rachat de Mercure.\r\r\n\r\r\n1976\r\r\n\r\r\n\xe2\x80\xa2 Mise en place d\xe2\x80\x99une structure au Br\xc3\xa9sil.\r\r\n\r\r\n1980\r\r\n\r\r\n\xe2\x80\xa2 Reprise de Sofitel (43 h\xc3\xb4tels et deux centres\r\r\n\r\r\n\xe2\x80\xa2 Le d\xc3\xa9veloppement des titres de service a permis\r\r\n\r\r\nde thalassoth\xc3\xa9rapie).\r\r\n\r\r\nde doubler le march\xc3\xa9 en trois ans (10 millions\r\r\n\r\r\n1981\r\r\n\r\r\n\xe2\x80\xa2 Introduction en Bourse de SIEH.\r\r\n\r\r\nd\xe2\x80\x99utilisateurs / jour).\r\r\n\r\r\n1982\r\r\n\r\r\n\xe2\x80\xa2 Prise de contr\xc3\xb4le de Jacques Borel International,\r\r\n\r\r\n\xe2\x80\xa2 Cession de 80% de la participation dans les\r\r\n\r\r\nchef de file europ\xc3\xa9en de la restauration collective\r\r\n\r\r\nactivit\xc3\xa9s de restauration de concession.\r\r\n\r\r\n(G\xc3\xa9n\xc3\xa9rale de Restauration) et de la restauration de\r\r\n\r\r\n\xe2\x80\xa2 Lancement d\xe2\x80\x99un programme intensif de formation\r\r\n\r\r\nconcession (Caf\xc3\xa9 Route, L\xe2\x80\x99Arche), et leader mondial\r\r\n\r\r\net d\xe2\x80\x99information dans le domaine de la protection\r\r\n\r\r\npour l\xe2\x80\x99\xc3\xa9mission de Ticket Restaurant (165 millions\r\r\n\r\r\nde l\xe2\x80\x99environnement.\r\r\n\r\r\nactionnaire du leader mondial de la restauration\r\r\n\r\r\nde tickets distribu\xc3\xa9s par an dans 8 pays).\r\r\n\r\r\n1983\r\r\n\r\r\ncollective.\r\r\n\r\r\n1996\r\r\n\r\r\n1985\r\r\n\r\r\nnum\xc3\xa9ro un de l\xe2\x80\x99h\xc3\xb4tellerie de cette r\xc3\xa9gion.\r\r\n\xe2\x80\xa2 Ibis, Etap Hotel et Formule 1 sont regroup\xc3\xa9s sous\r\r\n\r\r\n\xe2\x80\xa2 Cr\xc3\xa9ation de Formule 1 : Accor cr\xc3\xa9e un nouveau\r\r\n\r\r\nl\xe2\x80\x99\xc3\xa9gide de la soci\xc3\xa9t\xc3\xa9 Sphere International.\r\r\n\r\r\nconcept d\xe2\x80\x99h\xc3\xb4tellerie, faisant appel \xc3\xa0 des techniques\r\r\n\r\r\n\xe2\x80\xa2 Lancement de la \xe2\x80\x9cCarte Compliment\xe2\x80\x9d en partenariat\r\r\n\r\r\nde construction et de gestion particuli\xc3\xa8rement\r\r\n\r\r\navec American Express.\r\r\n\r\r\nnovatrices.\r\r\n\xe2\x80\xa2 Cr\xc3\xa9ation de l\xe2\x80\x99Acad\xc3\xa9mie Accor, premi\xc3\xa8re universit\xc3\xa9\r\r\n\r\r\n1988\r\r\n\r\r\n1997\r\r\n\r\r\nPaul Dubrule et G\xc3\xa9rard P\xc3\xa9lisson deviennent\r\r\n\r\r\n\xe2\x80\xa2 Acquisition de Len\xc3\xb4tre (traiteur, restauration\r\r\n\r\r\nCo-Pr\xc3\xa9sidents du Conseil de Surveillance ; Jean-Marc\r\r\n\r\r\ngastronomique et \xc3\xa9cole de cuisine).\r\r\n\r\r\nEspalioux est nomm\xc3\xa9 Pr\xc3\xa9sident du Directoire Lancement du projet \xe2\x80\x9cAccor 2000\xe2\x80\x9d, avec notamment\r\r\n\r\r\n\xe2\x80\xa2 100 h\xc3\xb4tels nouveaux et 250 restaurants au cours\r\r\n\r\r\nla relance du d\xc3\xa9veloppement et le \xe2\x80\x9cbond en avant\r\r\ntechnologique\xe2\x80\x9d.\r\r\n\r\r\n\xe2\x80\xa2 Formule 1 pour la premi\x ...

